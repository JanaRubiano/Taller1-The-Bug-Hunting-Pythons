# %% [markdown]
# 3. Realice un programa que lea un número enteros y determine si es par o impar.

# %%
a = int(input("Ingrese el primer numero: "))

if a % 2 == 0:
    print('El número', a, 'es par.')
else:
    print('El número', a, 'es impar.')

# %% [markdown]
# 5. Realice un programa que lea tres números reales y determine si la suma de los dos primeros es mayor, menor o igual que el tercer número.

# %%
a : float
b : float
c : float
a = float(input("Ingrese el primer numero: ")) 
b = float(input("Ingrese el segundo numero: ")) 
c = float(input("Ingrese el tercer numero: ")) 
if a + b < c :
    print (a,"mas", b,"es menor que", c)
elif a + b > c :
    print (a,"mas", b,"es mayor que", c)
else: 
    print (a,"mas", b,"es igual que", c)

# %% [markdown]
# 7. Escriba un programa que pida 5 números reales y calcule las siguientes operaciones:
#
# El promedio
# La mediana
# El promedio multiplicativo (multilplica todos y luego calcula la raíz de la cantidad de operandos)
# Ordenar los números de forma ascendente
# Ordenar los números de forma descendente
# La potencia del mayor número elevado al menor número
# La raíz cúbica del menor número

# %%
a:float
b:float
c:float
d:float
e:float
a = float (input("Ingrese un numero"))
b = float (input("Ingrese un numero"))
c = float (input("Ingrese un numero"))
d = float (input("Ingrese un numero"))
e = float (input("Ingrese un numero"))
f = a + b + c + d + e
g = f/5
print ("Media:",g)

if a < b and a < c and a < d and a < e :
    primertermino = a
elif b < a and b < c and b < d and b < e :
    primertermino = b
elif c < b and c < a and c < d and c < e :
    primertermino = c
elif d < b and d < c and d < a and d < e :
    primertermino = d
else :
    primertermino = e

if a > b and a > c and a > d and a > e :
    ultimotermino = a
elif b > a and b > c and b > d and b > e :
    ultimotermino = b
elif c > b and c > a and c > d and c > e :
    ultimotermino = c
elif d > b and d > c and d > a and d > e :
    ultimotermino = d
elif e > b and e > c and e > d and e > a :
    ultimotermino = e

if (a > b and a < c and a < d and a < e) or (a > c and a < b and a < d and a < e) or (a > d and a < c and a < b and a < e) or (a > e and a < c and a < d and a < b) :
    segundotermino = a
elif (b > a and b < c and b < d and b < e) or (b > c and b < a and b < d and b < e) or (b > d and b < c and b < a and b < e) or (b > e and b < c and b < d and b < a) :
    segundotermino = b
elif (c > a and c < a and c < d and c < e) or (c > b and c < a and c < d and c < e) or (c > d and c < a and c < b and c < e) or (c > e and c < a and c < d and c < b) :
    segundotermino = c
elif (d > b and d < c and d < a and d < e) or (d > c and d < b and d < a and d < e) or (d > a and d < c and d < b and d < e) or (d > e and d < c and d < a and d < b) :
    segundotermino = d
elif (e > b and e < c and e < d and e < a) or (e > c and e < b and e < d and e < a) or (e > d and e < c and e < b and e < a) or (e > a and e < c and e < d and e < b) :
    segundotermino = e

if (a < b and a > c and a > d and a > e) or (a < c and a > b and a > d and a > e) or (a < d and a > c and a > b and a > e) or (a < e and a > c and a > d and a > b) :
    cuartotermino = a
elif (b < a and b > c and b > d and b > e) or (b < c and b > a and b > d and b > e) or (b < d and b > c and b > a and b > e) or (b < e and b > c and b > d and b > a) :
    cuartotermino = b
elif (c < a and c > a and c > d and c > e) or (c < b and c > a and c > d and c > e) or (c < d and c > a and c > b and c > e) or (c < e and c > a and c > d and c > b) :
    cuartotermino = c
elif (d < b and d > c and d > a and d > e) or (d < c and d > b and d > a and d > e) or (d < a and d > c and d > b and d > e) or (d < e and d > c and d > a and d > b) :
    cuartotermino = d
elif (e < b and e > c and e > d and e > a) or (e < c and e > b and e > d and e > a) or (e < d and e > c and e > b and e > a) or (e < a and e > c and e > d and e > b) :
    cuartotermino = e

if segundotermino < a < cuartotermino :
    tercertermino = a
elif segundotermino < b < cuartotermino :
    tercertermino = b
elif segundotermino < c < cuartotermino :
    tercertermino = c
elif segundotermino < d < cuartotermino :
    tercertermino = d
elif segundotermino < e < cuartotermino :
    tercertermino = e
print ("Mediana:",tercertermino)

h = (a*b*c*d*e)**0.20
print ("Promedio Multiplicativo:",h)

print (primertermino,"-",segundotermino,"-",tercertermino,"-",cuartotermino,"-",ultimotermino)
print (ultimotermino,"-",cuartotermino,"-",tercertermino,"-",segundotermino,"-",primertermino)
print (ultimotermino**primertermino)
print (primertermino**(1/3))

# %% [markdown]
# 9. Escriba un programa que reciba el nombre en minúsculas de un país de America y retorne la ciudad capital, si el país no pertenece al continente debe arrojar país no identificado.

# %%
lang = input("Escriba el nombre de un país a America (en minusculas) ")

if lang == "canadá" or lang == "canada":
  print("La capital de Canadá es Otawwa")
elif lang ==  "estados unidos" or lang == "usa" :
  print("La capital de USA es Washington DC")
elif lang == "méxico" or lang== "mexico":
  print("La capital de México es México DF")
elif lang == "belice":
  print("La capital de Belice es Belmopan")
elif lang == "costa rica":
  print("La capital de Costa Rica es San Jóse")
elif lang == "el salvador" or lang== "salvador": 
    print("La capital de El Salvador San Salvador")
elif lang == "guatemala":
    print("La capital de Guatemala es Ciudad de Guatemala")
elif lang =="honduras":
    print("La capital de Honduras es Tegucigalpa")
elif lang =="nicaragua":
    print("La capital de Nicaragua es Managua")
elif lang =="panamá" or lang == "panama":
    print("La capital de Panamá es Panamá")
elif lang == "argentina":
    print("La capital de Argentina es Buenos Aires")
elif lang == "bolivia":
    print("La capital de Bolivia es Sucre")
elif lang == "brasil":
    print("La capital de Brasil es Brasilia")
elif lang == "chile":
    print("La capital de Chile es Santiago de Chile")
elif lang == "colombia": 
    print("La capital de Colombia es Bogotá")
elif lang == "ecuador":
    print("La capital de Ecuador es Quito")
elif lang == "paraguay": 
    print("La capital de Paraguay es Asunción")
elif lang == "peru" or lang == "perú":
    print("La capital de Perú es Lima")
elif lang == "surinam": 
    print("La capital de Surinam es Parabarimo")
elif lang == "trinidad y tobago": 
    print("La capital de Trinidad y Tobago es Puerto España")
elif lang == "uruguay":
    print("La capital de Uruguay es Montevideo")
elif lang == "venezuela": 
    print("La capital de Venezuela es Caracas")
elif lang == "cuba":
    print("La capital de Cuba es La Habanna")
elif lang == "republica dominicana" or lang == "república dominicana": 
    print("La capital de La Repúblicla Dominicana es Santo Domingo")
else:
  print("País no identificado")
